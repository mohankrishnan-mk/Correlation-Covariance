# %%
#Define Covariance and explain how it differs from Correlation in terms of scale and interpretation?

"""
covariance tell only direction not strength
its direct to the relationship (positive or negative)
this is measure two numeric variable change together
covariance was depends of unit variable scale and range was not fixed

correlation measure strength and the direction both of a linear relationship between two numeric variable
correlation is standarzided,so its value always -1 and +1
correlation how can value
> 1 positive correlation
> 0 is no correlation
> -1 is negative correlation
"""
# Out:
# '\ncovariance tell only direction not strength\nits direct to the relationship (positive or negative)\nthis is measure two numeric variable change together\ncovariance was depends of unit variable scale and range was not fixed\n\ncorrelation measure strength and the direction both of a linear relationship between two numeric variable\ncorrelation is standarzided,so its value always -1 and +1\ncorrelation how can value\n> 1 positive correlation\n> 0 is no correlation\n> -1 is negative correlation\n'

# %%
# What does a positive, negative, and zero covariance indicate about the relationship between two variables?

"""
positive covariance
> variable move on same direction in chart X variable was increasing and also Y variable increasing
negative covariance
> variable move on opposite direction because X value was increasing but Y value is dicreasing
zero covariance
> no linear relationship
"""
# Out:
# '\npositive covariance\n> variable move on same direction in chart X variable was increasing and also Y variable increasing\nnegative covariance\n> variable move on opposite direction because X value was increasing but Y value is dicreasing\nzero covariance\n> no linear relationship\n'

# %%
 #Discuss the limitations of covariance as a measure of relationship between two variables. Why is correlation preferred in many cases?

 """
Because covariance was not standard in scale,unit depend only X & Y and comparied to hard

Correlation is standardized scale (-1 to +1),unit free and compared to easy

"""
# Out:
# '\nBecause covariance was not standard in scale,unit depend only X & Y and comparied to hard\n\nCorrelation is standardized scale (-1 to +1),unit free and compared to easy\n\n'

# %%
# Explain the difference between Pearson’s correlation coefficient and Spearman’s rank correlation coefficient. When would you prefer to use Spearman’s correlation?

"""
Pearson Correlation
> Linear relationship
> Normal distribution often assumed
> Sensitive to outliers

Searman Rank Correlation
> Monotonic relationship
> No normality assumption
> Less sensitive to outliers

"""
# Out:
# '\nPearson Correlation \n> Linear relationship\n> Normal distribution often assumed\n> Sensitive to outliers\n\nSearman Rank Correlation\n> Monotonic relationship\n> No normality assumption\n> Less sensitive to outliers \n\n'

# %%
# If the correlation coefficient between two variables X and Y is 0.85, interpret this value in context. Can you infer causation from this value? why or why not ?

"""
This correlation coefficient 0.85 is strong positive relationship between as X increased and Y tends to increase significanted.

"""
# Out:
# '\nThis correlation coefficient 0.85 is strong positive relationship between as X increased and Y tends to increase significanted.\n\n'

# %%
#Using the dataset below, calculate the covariance between X and Y.X - 2,4,6,8 and Y - 3,7,5,10

"""
Cov(X,Y)=19/4-1

Cov(X,Y)=6.33
positive relationship

"""
# Out:
# '\nCov(X,Y)=19/4-1\n\nCov(X,Y)=6.33\npositive relationship\n\n'

# %%
#Compute the Pearson correlation coefficient between variables A and B:A - 10,20,30,40,50 and B - 8,14,18,24,28

"""
∑(A−Aˉ)(B−Bˉ)=500
∑(A−Aˉ)2=1000
∑(𝐵−𝐵ˉ)2=275.2
r=1000×275.2​500​
r=0.95
very strong positive relationship

"""
# Out:
# '\n∑(A−Aˉ)(B−Bˉ)=500\n∑(A−Aˉ)2=1000\n∑(𝐵−𝐵ˉ)2=275.2\nr=1000×275.2\u200b500\u200b\nr=0.95\nvery strong positive relationship\n\n'

# %%
#The following table shows heights (in cm) and weights (in kg) of 5 students.Find the correlation coefficient between Height and Weight.height-150,160,165,170,180/weight-50,55,58,62,70.

"""
r=∑(x−xˉ)2∑(y−yˉ​)2/​∑(x−xˉ)(y−yˉ​)​
calculate the formula my answer was r = 0.99
this answer very strong possitive correlation between height and weight.

"""
# Out:
# '\nr=∑(x−xˉ)2∑(y−yˉ\u200b)2/\u200b∑(x−xˉ)(y−yˉ\u200b)\u200b\ncalculate the formula my answer was r = 0.99\nthis answer very strong possitive correlation between height and weight.\n\n'

# %%
# Given the dataset below, determine whether there is a positive or negative correlation between X and Y.(No need for exact calculation, just reasoning.)X values: 1, 2, 3, 4, 5/Y values: 15, 12, 9, 7, 3

"""
X value was increasing and Y value was decreasing
Its negative correlation.

"""
# Out:
# '\nX value was increasing and Y value was decreasing\nIts negative correlation.\n\n'

# %%
# Two investment portfolios have the following returns (%) over 5 years. Compute the covariance and correlation coefficient, and interpret whether the portfolios move together.

"""
x = 8+10+12+9+11/5 = 50/5 = 10
y = 6+9+11+8+10/5 = 44/5 = 8.8

X - 10 = -2+0+2-1+1 = 0
Y - 8.8 = -2.8+0.2-0.8+1.2 = 0

(X - 10)* (Y - 8.8) = 5.6+0+4.4+0.8+1.2 = 12

cov(X,Y) = 12/5 = 2.4
Portfolio A
∑(𝑋−𝑋ˉ)2=4+0+4+1+1=10
∑(X−Xˉ)2=4+0+4+1+1=10
σX=1.414

Portfolio B
∑(𝑌−𝑌ˉ)2=7.84+0.04+4.84+0.64+1.44=14.8
∑(Y−Yˉ)2=7.84+0.04+4.84+0.64+1.44=14.8
σY=1.72

r = cov(x,y)/(1.414*1.72)=0.98

portfolio A and B strong positive relationship

"""
# Out:
# '\nx = 8+10+12+9+11/5 = 50/5 = 10\ny = 6+9+11+8+10/5 = 44/5 = 8.8\n\nX - 10 = -2+0+2-1+1 = 0\nY - 8.8 = -2.8+0.2-0.8+1.2 = 0\n\n(X - 10)* (Y - 8.8) = 5.6+0+4.4+0.8+1.2 = 12\n\ncov(X,Y) = 12/5 = 2.4\nPortfolio A\n∑(𝑋−𝑋ˉ)2=4+0+4+1+1=10\n∑(X−Xˉ)2=4+0+4+1+1=10\nσX=1.414\n\nPortfolio B\n∑(𝑌−𝑌ˉ)2=7.84+0.04+4.84+0.64+1.44=14.8\n∑(Y−Yˉ)2=7.84+0.04+4.84+0.64+1.44=14.8\nσY=1.72\n\nr = cov(x,y)/(1.414*1.72)=0.98\n \nportfolio A and B strong positive relationship\n\n'
